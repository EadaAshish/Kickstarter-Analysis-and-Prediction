# %%
import pandas as pd
import numpy as np

# %%
kick_all = pd.read_csv('Final_All.csv')
# Out:
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:3361: DtypeWarning: Columns (14,18,20,24,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
kick_all.shape
# Out:
# (221247, 47)

# %%
kick_all.head()
# Out:
#    backers_count                                              blurb  \
# 0             45  Taking you inside and outside of prison, and a...
# 1             21  A podcast of working at a tech company in the ...
# 2            146  A live morning radio show broadcasted online e...
# 3             31  For Season 9 of the Clive Barker Podcast and n...
# 4              9  A 16 page Zine filled with articles, reviews a...
#
#                                             category  \
# 0  {"id":357,"name":"Audio","analytics_name":"Aud...
# 1  {"id":357,"name":"Audio","analytics_name":"Aud...
# 2  {"id":357,"name":"Audio","analytics_name":"Aud...
# 3  {"id":357,"name":"Audio","analytics_name":"Aud...
# 4  {"id":357,"name":"Audio","analytics_name":"Aud...
#
#    converted_pledged_amount country country_displayable_name  created_at  \
# 0                      4506      US        the United States  1577743896
# 1                       322      US        the United States  1573666016
# ...

# %%
kick_all.columns
# Out:
# Index(['backers_count', 'blurb', 'category', 'converted_pledged_amount',
#        'country', 'country_displayable_name', 'created_at', 'creator',
#        'currency', 'currency_symbol', 'currency_trailing_code',
#        'current_currency', 'deadline', 'disable_communication', 'friends',
#        'fx_rate', 'goal', 'id', 'is_backing', 'is_starrable', 'is_starred',
#        'launched_at', 'location', 'name', 'permissions', 'photo', 'pledged',
#        'profile', 'slug', 'source_url', 'spotlight', 'staff_pick', 'state',
#        'state_changed_at', 'static_usd_rate', 'urls', 'usd_exchange_rate',
#        'usd_pledged', 'usd_type', 'profit', 'class', 'Index', 'Urls', 'Text',
#        'Score', 'Comments', 'Updates'],
#       dtype='object')

# %%
kick_all['profit'][1]
# Out:
# 22.0

# %%
kick_all['index'] = np.arange(len(kick_all))

# %%
kick_all['index']
# Out:
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
#            ...
# 221242    221242
# 221243    221243
# 221244    221244
# 221245    221245
# 221246    221246
# Name: index, Length: 221247, dtype: int32

# %%
urls = []
for pos in range(kick_all.shape[0]):
    val = eval(kick_all['urls'][pos])
    urls.append(val['web']['project'])
urls
# Out:
# ['https://www.kickstarter.com/projects/atnightifly/at-night-i-fly?ref=discovery_category_newest',
#  'https://www.kickstarter.com/projects/saasgraveyard/podcast-tales-from-the-saas-graveyard?ref=discovery_category_newest',
#  'https://www.kickstarter.com/projects/gottsnack/gott-snack-granslos-morgonradio?ref=discovery_category_newest',
#  'https://www.kickstarter.com/projects/barkercastfr7/clive-barker-podcast-presents-fundraiser-vii-debtor?ref=discovery_category_newest',
#  'https://www.kickstarter.com/projects/zine-issue-3/zine-issue-3-the-de-broize-custom-drums-journey?ref=discovery_category_newest',
#  'https://www.kickstarter.com/projects/howcanwepodcast/how-can-we-talk-to-people-who-do-not-agree-with-us?ref=discovery_category_newest',
#  'https://www.kickstarter.com/projects/breenaelysekerr/liliass-bones-a-witch-podcast?ref=discovery_category_newest',
#  'https://www.kickstarter.com/projects/dahlgaardstivoli/mandrilaftale-podcasten-episode-1-7?ref=discovery_category_newest',
# ...

# %%
url_list = pd.DataFrame(urls,columns=['web_url'])

# %%
url_list
# Out:
#                                                   web_url
# 0       https://www.kickstarter.com/projects/atnightif...
# 1       https://www.kickstarter.com/projects/saasgrave...
# 2       https://www.kickstarter.com/projects/gottsnack...
# 3       https://www.kickstarter.com/projects/barkercas...
# 4       https://www.kickstarter.com/projects/zine-issu...
# ...                                                   ...
# 221242  https://www.kickstarter.com/projects/206254851...
# 221243  https://www.kickstarter.com/projects/990556221...
# 221244  https://www.kickstarter.com/projects/417ballz/...
# 221245  https://www.kickstarter.com/projects/148177769...
# 221246  https://www.kickstarter.com/projects/josemox/f...
#
# [221247 rows x 1 columns]

# %%
kick = pd.concat([kick_all, url_list], axis=1)
kick
# Out:
#         backers_count                                              blurb  \
# 0                  45  Taking you inside and outside of prison, and a...
# 1                  21  A podcast of working at a tech company in the ...
# 2                 146  A live morning radio show broadcasted online e...
# 3                  31  For Season 9 of the Clive Barker Podcast and n...
# 4                   9  A 16 page Zine filled with articles, reviews a...
# ...               ...                                                ...
# 221242              0  Our mission is to start a Live Action Role Pla...
# 221243              4  A cat cafe in Hertfordshire. A place for rescu...
# 221244              5  We are trying to turn our very small, catering...
# 221245              0  ¡Helado en forma de Rollitos! Algo exotico y d...
# 221246            102  New miniatures for the Asgard´s Sons and Artem...
#
#                                                  category  \
# ...

# %%
kick[kick['class'] == 1]
# Out:
#         backers_count                                              blurb  \
# 0                  45  Taking you inside and outside of prison, and a...
# 1                  21  A podcast of working at a tech company in the ...
# 2                 146  A live morning radio show broadcasted online e...
# 3                  31  For Season 9 of the Clive Barker Podcast and n...
# 4                   9  A 16 page Zine filled with articles, reviews a...
# ...               ...                                                ...
# 221232            137  A heavily branching visual novel, featuring lo...
# 221239             15                 3d STL files for warhammer village
# 221240            873  A mystery adventure that merges puzzles with v...
# 221241            414  A rad oracle deck for all stitchers. Gain insi...
# 221246            102  New miniatures for the Asgard´s Sons and Artem...
#
#                                                  category  \
# ...

# %%
kick['web_url']
# Out:
# 0         https://www.kickstarter.com/projects/atnightif...
# 1         https://www.kickstarter.com/projects/saasgrave...
# 2         https://www.kickstarter.com/projects/gottsnack...
# 3         https://www.kickstarter.com/projects/barkercas...
# 4         https://www.kickstarter.com/projects/zine-issu...
#                                 ...
# 221242    https://www.kickstarter.com/projects/206254851...
# 221243    https://www.kickstarter.com/projects/990556221...
# 221244    https://www.kickstarter.com/projects/417ballz/...
# 221245    https://www.kickstarter.com/projects/148177769...
# 221246    https://www.kickstarter.com/projects/josemox/f...
# Name: web_url, Length: 221247, dtype: object

# %%
temp = kick[kick['class'] == 1][['web_url']]
temp
# Out:
#                                                   web_url
# 0       https://www.kickstarter.com/projects/atnightif...
# 1       https://www.kickstarter.com/projects/saasgrave...
# 2       https://www.kickstarter.com/projects/gottsnack...
# 3       https://www.kickstarter.com/projects/barkercas...
# 4       https://www.kickstarter.com/projects/zine-issu...
# ...                                                   ...
# 221232  https://www.kickstarter.com/projects/scribble-...
# 221239  https://www.kickstarter.com/projects/tartaro/t...
# 221240  https://www.kickstarter.com/projects/ricethin/...
# 221241  https://www.kickstarter.com/projects/stitchtog...
# 221246  https://www.kickstarter.com/projects/josemox/f...
#
# [134029 rows x 1 columns]

# %%
temp[15000:20000].to_excel('Urls_Succ.xlsx')
